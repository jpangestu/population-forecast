# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import os

# %%
regions = {
    'asia': {
        'southern-asia': [
            'india', 'pakistan', 'bangladesh', 'iran',
            'afghanistan', 'nepal', 'sri-lanka', 'bhutan', 'maldives'
        ],
        'eastern-asia': [
            'china', 'japan', 'south-korea', 'north-korea',
            'taiwan', 'china-hong-kong-sar', 'china-macao-sar', 'mongolia'
        ],
        'south-eastern-asia': [
            'indonesia', 'philippines', 'vietnam', 'thailand',
            'myanmar', 'malaysia', 'cambodia', 'laos',
            'singapore', 'timor-leste', 'brunei-darussalam'
        ],
        'western-asia': [
            'turkey', 'iraq', 'yemen', 'saudi-arabia', 'syria',
            'jordan', 'united-arab-emirates', 'azerbaijan',
            'israel', 'lebanon', 'state-of-palestine', 'oman',
            'kuwait', 'georgia', 'qatar', 'armenia',
            'bahrain', 'cyprus'
        ],
        'central-asia': [
            'kazakhstan', 'uzbekistan', 'turkmenistan',
            'tajikistan', 'kyrgyzstan'
        ]
    },
    'africa': {
        'eastern-africa': [
            'ethiopia', 'tanzania', 'kenya', 'uganda',
            'mozambique', 'madagascar', 'malawi', 'zambia',
            'somalia', 'zimbabwe', 'rwanda', 'burundi',
            'south-sudan', 'eritrea', 'mauritius', 'djibouti',
            'comoros', 'reunion', 'mayotte', 'seychelles'
        ],
        'western-africa': [
            'nigeria', 'ghana', 'cote-d-ivoire', 'niger',
            'mali', 'burkina-faso', 'senegal', 'guinea',
            'benin', 'togo', 'sierra-leone', 'liberia',
            'mauritania', 'gambia', 'guinea-bissau',
            'cabo-verde', 'saint-helena'
        ],
        'northern-africa': [
            'egypt', 'sudan', 'algeria', 'morocco',
            'tunisia', 'libya', 'western-sahara'
        ],
        'middle-africa': [
            'democratic-republic-of-the-congo', 'angola', 'cameroon', 'chad',
            'congo', 'central-african-republic', 'gabon',
            'equatorial-guinea', 'sao-tome-and-principe'
        ],
        'southern-africa': [
            'south-africa', 'namibia', 'botswana',
            'lesotho', 'swaziland'
        ]
    },
    'europe': {
        'eastern-europe': [
            'russia', 'ukraine', 'poland', 'romania',
            'czech-republic', 'hungary', 'belarus',
            'bulgaria', 'slovakia', 'moldova'
        ],
        'western-europe': [
            'germany', 'france', 'netherlands', 'belgium',
            'austria', 'switzerland', 'luxembourg', 'liechtenstein', 'monaco'
        ],
        'southern-europe': [
            'italy', 'spain', 'portugal', 'greece',
            'croatia', 'slovenia', 'serbia', 'bosnia-and-herzegovina',
            'north-macedonia', 'albania', 'montenegro', 'andorra',
            'san-marino', 'malta'
        ],
        'northern-europe': [
            'uk', 'ireland', 'denmark',
            'sweden', 'finland', 'norway', 'iceland',
            'estonia', 'latvia', 'lithuania'
        ]
    },
    'latin-america-and-the-caribbean': {
        'south-america': [
            'brazil', 'colombia', 'argentina', 'peru',
            'venezuela', 'chile', 'ecuador', 'bolivia',
            'paraguay', 'uruguay', 'guyana', 'suriname'
        ],
        'central-america': [
            'mexico', 'guatemala', 'honduras', 'nicaragua',
            'el-salvador', 'costa-rica', 'panama', 'belize'
        ],
        'caribbean': [
            'cuba', 'haiti', 'dominican-republic', 'jamaica',
            'trinidad-and-tobago', 'bahamas', 'barbados',
            'saint-lucia', 'saint-vincent-and-the-grenadines',
            'grenada', 'antigua-and-barbuda', 'dominica',
            'saint-kitts-and-nevis'
        ]
    },
    'northern-america': {
        'northern-america': [
            'us', 'canada', 'bermuda'
        ]
    },
    'oceania': {
        'australia-and-new-zealand': [
            'australia', 'new-zealand'
        ],
        'melanesia': [
            'papua-new-guinea', 'fiji', 'solomon-islands',
            'vanuatu'
        ],
        'polynesia': [
            'samoa', 'tonga', 'tuvalu'
        ],
        'micronesia': [
            'micronesia', 'marshall-islands', 'palau',
            'nauru', 'kiribati'
        ]
    }
}

# %%
def scrapp_worldometers(regions, folder_path):
  country_option_list = []
  for continent, subregions in regions.items():
      for subregion, countries in subregions.items():
          for country in countries:
                base_url = "https://www.worldometers.info/world-population/"
                url = base_url + country + "-population/"
                print(f"Scraping: {url}")

                try:
                    response = requests.get(url)
                    response.raise_for_status()
                except requests.exceptions.RequestException as e:
                    print(f"Error fetching {url}: {e}")
                    continue

                soup = BeautifulSoup(response.content, "html.parser")
                table = soup.find("table", attrs={"class": lambda x: x and "table" in x})

                if table is None:
                    print(f"Warning: Population table not found for {country}. Skipping.")
                    continue

                headers = [th.text.strip() for th in table.find_all("th")]

                rows = []
                for tr in table.tbody.find_all("tr"):
                    cells = [td.text.strip().replace(",", "") for td in tr.find_all("td")]
                    rows.append(cells)

                df = pd.DataFrame(rows, columns=headers)

                if 'Year' in df.columns:
                    df = df.sort_values('Year')
                else:
                    print(f"Warning: 'Year' column not found for {country}. Skipping sorting.")

                # Ensure subfolder exists for continent/subregion
                dir_path = os.path.join(folder_path, continent, subregion)
                os.makedirs(dir_path, exist_ok=True)

                file_path = os.path.join(dir_path, f"{country}.csv")
                df.to_csv(file_path, index=False)

                option_label = (country.title(), file_path)
                country_option_list.append(option_label)

  return country_option_list # return list of each file_path

# %%
country_option_list = scrapp_worldometers(regions, '../raw_data')
# Out:
# Scraping: https://www.worldometers.info/world-population/india-population/
# Scraping: https://www.worldometers.info/world-population/pakistan-population/
# Scraping: https://www.worldometers.info/world-population/bangladesh-population/
# Scraping: https://www.worldometers.info/world-population/iran-population/
# Scraping: https://www.worldometers.info/world-population/afghanistan-population/
# Scraping: https://www.worldometers.info/world-population/nepal-population/
# Scraping: https://www.worldometers.info/world-population/sri-lanka-population/
# Scraping: https://www.worldometers.info/world-population/bhutan-population/
# Scraping: https://www.worldometers.info/world-population/maldives-population/
# Scraping: https://www.worldometers.info/world-population/china-population/
# Scraping: https://www.worldometers.info/world-population/japan-population/
# Scraping: https://www.worldometers.info/world-population/south-korea-population/
# Scraping: https://www.worldometers.info/world-population/north-korea-population/
# Scraping: https://www.worldometers.info/world-population/taiwan-population/
# Scraping: https://www.worldometers.info/world-population/china-hong-kong-sar-population/
# Scraping: https://www.worldometers.info/world-population/china-macao-sar-population/
# Scraping: https://www.worldometers.info/world-population/mongolia-population/
# Scraping: https://www.worldometers.info/world-population/indonesia-population/
# Scraping: https://www.worldometers.info/world-population/philippines-population/
# Scraping: https://www.worldometers.info/world-population/vietnam-population/
# Scraping: https://www.worldometers.info/world-population/thailand-population/
# Scraping: https://www.worldometers.info/world-population/myanmar-population/
# Scraping: https://www.worldometers.info/world-population/malaysia-population/
# Scraping: https://www.worldometers.info/world-population/cambodia-population/
# Scraping: https://www.worldometers.info/world-population/laos-population/
# Scraping: https://www.worldometers.info/world-population/singapore-population/
# Scraping: https://www.worldometers.info/world-population/timor-leste-population/
# Scraping: https://www.worldometers.info/world-population/brunei-darussalam-population/
# Scraping: https://www.worldometers.info/world-population/turkey-population/
# Scraping: https://www.worldometers.info/world-population/iraq-population/
# Scraping: https://www.worldometers.info/world-population/yemen-population/
# Scraping: https://www.worldometers.info/world-population/saudi-arabia-population/
# Scraping: https://www.worldometers.info/world-population/syria-population/
# Scraping: https://www.worldometers.info/world-population/jordan-population/
# Scraping: https://www.worldometers.info/world-population/united-arab-emirates-population/
# Scraping: https://www.worldometers.info/world-population/azerbaijan-population/
# Scraping: https://www.worldometers.info/world-population/israel-population/
# Scraping: https://www.worldometers.info/world-population/lebanon-population/
# Scraping: https://www.worldometers.info/world-population/state-of-palestine-population/
# Scraping: https://www.worldometers.info/world-population/oman-population/
# Scraping: https://www.worldometers.info/world-population/kuwait-population/
# Scraping: https://www.worldometers.info/world-population/georgia-population/
# Scraping: https://www.worldometers.info/world-population/qatar-population/
# Scraping: https://www.worldometers.info/world-population/armenia-population/
# Scraping: https://www.worldometers.info/world-population/bahrain-population/
# Scraping: https://www.worldometers.info/world-population/cyprus-population/
# Scraping: https://www.worldometers.info/world-population/kazakhstan-population/
# Scraping: https://www.worldometers.info/world-population/uzbekistan-population/
# Scraping: https://www.worldometers.info/world-population/turkmenistan-population/
# Scraping: https://www.worldometers.info/world-population/tajikistan-population/
# Scraping: https://www.worldometers.info/world-population/kyrgyzstan-population/
# Scraping: https://www.worldometers.info/world-population/ethiopia-population/
# Scraping: https://www.worldometers.info/world-population/tanzania-population/
# Scraping: https://www.worldometers.info/world-population/kenya-population/
# Scraping: https://www.worldometers.info/world-population/uganda-population/
# Scraping: https://www.worldometers.info/world-population/mozambique-population/
# Scraping: https://www.worldometers.info/world-population/madagascar-population/
# Scraping: https://www.worldometers.info/world-population/malawi-population/
# Scraping: https://www.worldometers.info/world-population/zambia-population/
# Scraping: https://www.worldometers.info/world-population/somalia-population/
# Scraping: https://www.worldometers.info/world-population/zimbabwe-population/
# Scraping: https://www.worldometers.info/world-population/rwanda-population/
# Scraping: https://www.worldometers.info/world-population/burundi-population/
# Scraping: https://www.worldometers.info/world-population/south-sudan-population/
# Scraping: https://www.worldometers.info/world-population/eritrea-population/
# Scraping: https://www.worldometers.info/world-population/mauritius-population/
# Scraping: https://www.worldometers.info/world-population/djibouti-population/
# Scraping: https://www.worldometers.info/world-population/comoros-population/
# Scraping: https://www.worldometers.info/world-population/reunion-population/
# Scraping: https://www.worldometers.info/world-population/mayotte-population/
# Scraping: https://www.worldometers.info/world-population/seychelles-population/
# Scraping: https://www.worldometers.info/world-population/nigeria-population/
# Scraping: https://www.worldometers.info/world-population/ghana-population/
# Scraping: https://www.worldometers.info/world-population/cote-d-ivoire-population/
# Scraping: https://www.worldometers.info/world-population/niger-population/
# Scraping: https://www.worldometers.info/world-population/mali-population/
# Scraping: https://www.worldometers.info/world-population/burkina-faso-population/
# Scraping: https://www.worldometers.info/world-population/senegal-population/
# Scraping: https://www.worldometers.info/world-population/guinea-population/
# Scraping: https://www.worldometers.info/world-population/benin-population/
# Scraping: https://www.worldometers.info/world-population/togo-population/
# Scraping: https://www.worldometers.info/world-population/sierra-leone-population/
# Scraping: https://www.worldometers.info/world-population/liberia-population/
# Scraping: https://www.worldometers.info/world-population/mauritania-population/
# Scraping: https://www.worldometers.info/world-population/gambia-population/
# Scraping: https://www.worldometers.info/world-population/guinea-bissau-population/
# Scraping: https://www.worldometers.info/world-population/cabo-verde-population/
# Scraping: https://www.worldometers.info/world-population/saint-helena-population/
# Scraping: https://www.worldometers.info/world-population/egypt-population/
# Scraping: https://www.worldometers.info/world-population/sudan-population/
# Scraping: https://www.worldometers.info/world-population/algeria-population/
# Scraping: https://www.worldometers.info/world-population/morocco-population/
# Scraping: https://www.worldometers.info/world-population/tunisia-population/
# Scraping: https://www.worldometers.info/world-population/libya-population/
# Scraping: https://www.worldometers.info/world-population/western-sahara-population/
# Scraping: https://www.worldometers.info/world-population/democratic-republic-of-the-congo-population/
# Scraping: https://www.worldometers.info/world-population/angola-population/
# Scraping: https://www.worldometers.info/world-population/cameroon-population/
# Scraping: https://www.worldometers.info/world-population/chad-population/
# Scraping: https://www.worldometers.info/world-population/congo-population/
# Scraping: https://www.worldometers.info/world-population/central-african-republic-population/
# Scraping: https://www.worldometers.info/world-population/gabon-population/
# Scraping: https://www.worldometers.info/world-population/equatorial-guinea-population/
# Scraping: https://www.worldometers.info/world-population/sao-tome-and-principe-population/
# Scraping: https://www.worldometers.info/world-population/south-africa-population/
# Scraping: https://www.worldometers.info/world-population/namibia-population/
# Scraping: https://www.worldometers.info/world-population/botswana-population/
# Scraping: https://www.worldometers.info/world-population/lesotho-population/
# Scraping: https://www.worldometers.info/world-population/swaziland-population/
# Scraping: https://www.worldometers.info/world-population/russia-population/
# Scraping: https://www.worldometers.info/world-population/ukraine-population/
# Scraping: https://www.worldometers.info/world-population/poland-population/
# Scraping: https://www.worldometers.info/world-population/romania-population/
# Scraping: https://www.worldometers.info/world-population/czech-republic-population/
# Scraping: https://www.worldometers.info/world-population/hungary-population/
# Scraping: https://www.worldometers.info/world-population/belarus-population/
# Scraping: https://www.worldometers.info/world-population/bulgaria-population/
# Scraping: https://www.worldometers.info/world-population/slovakia-population/
# Scraping: https://www.worldometers.info/world-population/moldova-population/
# Scraping: https://www.worldometers.info/world-population/germany-population/
# Scraping: https://www.worldometers.info/world-population/france-population/
# Scraping: https://www.worldometers.info/world-population/netherlands-population/
# Scraping: https://www.worldometers.info/world-population/belgium-population/
# Scraping: https://www.worldometers.info/world-population/austria-population/
# Scraping: https://www.worldometers.info/world-population/switzerland-population/
# Scraping: https://www.worldometers.info/world-population/luxembourg-population/
# Scraping: https://www.worldometers.info/world-population/liechtenstein-population/
# Scraping: https://www.worldometers.info/world-population/monaco-population/
# Scraping: https://www.worldometers.info/world-population/italy-population/
# Scraping: https://www.worldometers.info/world-population/spain-population/
# Scraping: https://www.worldometers.info/world-population/portugal-population/
# Scraping: https://www.worldometers.info/world-population/greece-population/
# Scraping: https://www.worldometers.info/world-population/croatia-population/
# Scraping: https://www.worldometers.info/world-population/slovenia-population/
# Scraping: https://www.worldometers.info/world-population/serbia-population/
# Scraping: https://www.worldometers.info/world-population/bosnia-and-herzegovina-population/
# Scraping: https://www.worldometers.info/world-population/north-macedonia-population/
# Scraping: https://www.worldometers.info/world-population/albania-population/
# Scraping: https://www.worldometers.info/world-population/montenegro-population/
# Scraping: https://www.worldometers.info/world-population/andorra-population/
# Scraping: https://www.worldometers.info/world-population/san-marino-population/
# Scraping: https://www.worldometers.info/world-population/malta-population/
# Scraping: https://www.worldometers.info/world-population/uk-population/
# Scraping: https://www.worldometers.info/world-population/ireland-population/
# Scraping: https://www.worldometers.info/world-population/denmark-population/
# Scraping: https://www.worldometers.info/world-population/sweden-population/
# Scraping: https://www.worldometers.info/world-population/finland-population/
# Scraping: https://www.worldometers.info/world-population/norway-population/
# Scraping: https://www.worldometers.info/world-population/iceland-population/
# Scraping: https://www.worldometers.info/world-population/estonia-population/
# Scraping: https://www.worldometers.info/world-population/latvia-population/
# Scraping: https://www.worldometers.info/world-population/lithuania-population/
# Scraping: https://www.worldometers.info/world-population/brazil-population/
# Scraping: https://www.worldometers.info/world-population/colombia-population/
# Scraping: https://www.worldometers.info/world-population/argentina-population/
# Scraping: https://www.worldometers.info/world-population/peru-population/
# Scraping: https://www.worldometers.info/world-population/venezuela-population/
# Scraping: https://www.worldometers.info/world-population/chile-population/
# Scraping: https://www.worldometers.info/world-population/ecuador-population/
# Scraping: https://www.worldometers.info/world-population/bolivia-population/
# Scraping: https://www.worldometers.info/world-population/paraguay-population/
# Scraping: https://www.worldometers.info/world-population/uruguay-population/
# Scraping: https://www.worldometers.info/world-population/guyana-population/
# Scraping: https://www.worldometers.info/world-population/suriname-population/
# Scraping: https://www.worldometers.info/world-population/mexico-population/
# Scraping: https://www.worldometers.info/world-population/guatemala-population/
# Scraping: https://www.worldometers.info/world-population/honduras-population/
# Scraping: https://www.worldometers.info/world-population/nicaragua-population/
# Scraping: https://www.worldometers.info/world-population/el-salvador-population/
# Scraping: https://www.worldometers.info/world-population/costa-rica-population/
# Scraping: https://www.worldometers.info/world-population/panama-population/
# Scraping: https://www.worldometers.info/world-population/belize-population/
# Scraping: https://www.worldometers.info/world-population/cuba-population/
# Scraping: https://www.worldometers.info/world-population/haiti-population/
# Scraping: https://www.worldometers.info/world-population/dominican-republic-population/
# Scraping: https://www.worldometers.info/world-population/jamaica-population/
# Scraping: https://www.worldometers.info/world-population/trinidad-and-tobago-population/
# Scraping: https://www.worldometers.info/world-population/bahamas-population/
# Scraping: https://www.worldometers.info/world-population/barbados-population/
# Scraping: https://www.worldometers.info/world-population/saint-lucia-population/
# Scraping: https://www.worldometers.info/world-population/saint-vincent-and-the-grenadines-population/
# Scraping: https://www.worldometers.info/world-population/grenada-population/
# Scraping: https://www.worldometers.info/world-population/antigua-and-barbuda-population/
# Scraping: https://www.worldometers.info/world-population/dominica-population/
# Scraping: https://www.worldometers.info/world-population/saint-kitts-and-nevis-population/
# Scraping: https://www.worldometers.info/world-population/us-population/
# Scraping: https://www.worldometers.info/world-population/canada-population/
# Scraping: https://www.worldometers.info/world-population/bermuda-population/
# Scraping: https://www.worldometers.info/world-population/australia-population/
# Scraping: https://www.worldometers.info/world-population/new-zealand-population/
# Scraping: https://www.worldometers.info/world-population/papua-new-guinea-population/
# Scraping: https://www.worldometers.info/world-population/fiji-population/
# Scraping: https://www.worldometers.info/world-population/solomon-islands-population/
# Scraping: https://www.worldometers.info/world-population/vanuatu-population/
# Scraping: https://www.worldometers.info/world-population/samoa-population/
# Scraping: https://www.worldometers.info/world-population/tonga-population/
# Scraping: https://www.worldometers.info/world-population/tuvalu-population/
# Scraping: https://www.worldometers.info/world-population/micronesia-population/
# Scraping: https://www.worldometers.info/world-population/marshall-islands-population/
# Scraping: https://www.worldometers.info/world-population/palau-population/
# Scraping: https://www.worldometers.info/world-population/nauru-population/
# Scraping: https://www.worldometers.info/world-population/kiribati-population/
